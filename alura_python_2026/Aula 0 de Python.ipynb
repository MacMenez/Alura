# %%
'roxo'
# Out:
# 'roxo'

# %%
'Davi'
# Out:
# 'Davi'

# %%
'Queen'
# Out:
# 'Queen'

# %%
print('Boas Vindas a aula de Python')
# Out:
# Boas Vindas a aula de Python

# %%
PRINT('Boas Vindas)
# Out:
#   File "/tmp/ipython-input-3510517839.py", line 1
#     PRINT('Boas Vindas)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Boas Vindas a aula de Python'
# Out:
#   File "/tmp/ipython-input-957178708.py", line 1
#     print('Boas Vindas a aula de Python'
#                                         ^
# SyntaxError: incomplete input

# %%
print('Boas Vindas a aula de Python)
# Out:
#   File "/tmp/ipython-input-826857490.py", line 1
#     print('Boas Vindas a aula de Python)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'variaveis'
# Out:
# 'variaveis'

# %%
nome = 'Davi'

# %%
nome
# Out:
# 'Davi'

# %%
cor favorita = 'roxo'
# Out:
#   File "/tmp/ipython-input-736488866.py", line 1
#     cor favorita = 'roxo'
#         ^
# SyntaxError: invalid syntax

# %%
cor_favorita = 'roxo'

# %%
print(nome, cor_favorita)
# Out:
# Davi roxo

# %%
saldo = 5000

# %%
saldo
# Out:
# 5000

# %%
saldo = saldo + 2000

# %%
saldo
# Out:
# 7000

# %%
print(saldo)
# Out:
# 7000

# %%
print('R$', saldo)
# Out:
# R$ 7000

# %%
print('Saldo na sua conta: R$', saldo)
# Out:
# Saldo na sua conta: R$ 7000

# %%
saldo = saldo - 500

# %%
print('Saldo na sua conta: R$', saldo)
# Out:
# Saldo na sua conta: R$ 6500

# %%
saldo = saldo * 2

# %%
print('Saldo na sua conta: R$', saldo)
# Out:
# Saldo na sua conta: R$ 13000

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
idade = 16
se idade for maior que 16
pode dirigir
senão
não pode dirigir
# Out:
#   File "/tmp/ipython-input-2925203229.py", line 2
#     se idade for maior que 16
#        ^
# SyntaxError: invalid syntax

# %%
idade = 16 # testar com 5, 17, 65, 18
#se idade for maior que 16
if idade > 18:
    #pode dirigir
    print('Pode dirigir')
#senão
else:
    #não pode dirigir
    print('Não pode dirigir')
# Out:
# Não pode dirigir

# %%
#isso é um comentário

# %%
idade = 18
#se idade for maior que 16
if idade >= 18:
    #pode dirigir
    print('Pode dirigir')
#senão
else:
    #não pode dirigir
    print('Não pode dirigir')
# Out:
# Pode dirigir
